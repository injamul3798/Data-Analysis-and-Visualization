# %%
'''Pandas uses the plot() method to create diagrams.

We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

Read more about Matplotlib in our Matplotlib Tutorial.'''
import pandas as pd
import matplotlib.pyplot as plt  # we just have to import this to show the plot
df = pd.read_csv("C:\\Users\\HP\Documents\\Data Science\\Pandas\\weather_data1.csv")
df.plot()   #plot method is used for plotting here
plt.show()
